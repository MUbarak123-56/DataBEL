# %% [markdown]
# # PREMIER LEAGUE MID-SEASON ANALYSIS

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_e62b6c1bb76c4710b1d1cc5aeab9a929 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='9ZymKSD_6E0Aw3YRO1fn1RBF95BmxW_zKvIslTE4CC4g',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_e62b6c1bb76c4710b1d1cc5aeab9a929.get_object(Bucket='databel-donotdelete-pr-d4qsbyzwywn9lq',Key='PREMIER LEAGUE TABLE - Sheet1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    Position                     Team  GP   W  D  L  GF  GA  GD  Points
# 0         1             Liverpool FC  18  17  1  0  46  14  32      52
# 1         2           Leicester City  19  12  3  4  41  18  23      39
# 2         3          Manchester City  19  12  2  5  52  23  29      38
# 3         4                  Chelsea  19  10  2  7  33  27   6      32
# 4         5  Wolverhampton Wanderers  19   7  9  3  29  24   5      30

# %%
df_table = df_data_1

# %%
df_table['Team'] = df_table['Team'].replace({"Liverpool FC":"Liverpool"})

# %%
df_table
# Out:
#     Position                     Team  GP   W  D   L  GF  GA  GD  Points
# 0          1                Liverpool  18  17  1   0  46  14  32      52
# 1          2           Leicester City  19  12  3   4  41  18  23      39
# 2          3          Manchester City  19  12  2   5  52  23  29      38
# 3          4                  Chelsea  19  10  2   7  33  27   6      32
# 4          5  Wolverhampton Wanderers  19   7  9   3  29  24   5      30
# 5          6        Tottenham Hotspur  19   8  5   6  34  27   7      29
# 6          7         Sheffield United  19   7  8   4  23  17   6      29
# 7          8        Manchester United  19   7  7   5  30  23   7      28
# 8          9           Crystal Palace  19   7  5   7  17  21  -4      26
# 9         10         Newcastle United  19   7  4   8  19  28  -9      25
# 10        11                  Arsenal  19   5  9   5  25  28  -3      24
# 11        12                  Burnley  19   7  3   9  23  30  -7      24
# ...

# %% [markdown]
# ## DATA ANALYSIS

# %%
## Importing Data Visualization packages
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### BIGGEST WINNERS

# %%
df_table1 = df_table[["Team", "W"]].sort_values(by = 'W', ascending = True)

# %%
ind = df_table1.set_index("Team", inplace = True)

# %%
## A horizontal bar graph showing the biggest winners of the premier league after 19 games
bar = df_table1.plot(kind='barh',figsize=(30, 16), color = "blue", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind,fontsize = 18)
plt.ylabel("")
plt.title("The biggest winners of the premier league mid-season of 2019/20", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ### BIGGEST LOSERS

# %%
df_table2 = df_table[["Team", "L"]].sort_values(by = 'L', ascending = True)

# %%
ind2 = df_table2.set_index("Team", inplace = True)

# %%
## A horizontal bar graph showing the biggest losers of the premier league after 19 games
bar = df_table2.plot(kind='barh',figsize=(30, 16), color = "red", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind2,fontsize = 18)
plt.ylabel("")
plt.title("The biggest losers of the premier league mid-season of 2019/20", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ### WHO HAS SCORED THE MOST?

# %%
df_table3 = df_table[["Team", "GF"]].sort_values(by = 'GF', ascending = True)

# %%
ind3 = df_table3.set_index("Team", inplace = True)

# %%
## A horizontal bar graph showing who has scored the most goals in the premier league after 19 games
bar = df_table3.plot(kind='barh',figsize=(30, 16), color = "blue", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind3,fontsize = 18)
plt.ylabel("")
plt.title("Goals scored in the premier league mid-season of 2019/20", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ### WHO HAS CONCEDED THE MOST?

# %%
df_table4 = df_table[["Team", "GA"]].sort_values(by = 'GA', ascending = True)

# %%
ind4 = df_table4.set_index("Team", inplace = True)

# %%
## A horizontal bar graph showing who has conceded the most goals in the premier league after 19 games
bar = df_table4.plot(kind='barh',figsize=(30, 16), color = "red", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind4,fontsize = 18)
plt.ylabel("")
plt.title("Goals conceded in the premier league mid-season of 2019/20", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ### WHO LOVES SHARING POINTS THE MOST?

# %%
df_table5 = df_table[["Team", "D"]].sort_values(by = 'D', ascending = True)

# %%
ind5 = df_table5.set_index("Team", inplace = True)

# %%
## A horizontal bar graph showing which team has tied most of its games in the premier league after 19 games
bar = df_table5.plot(kind='barh',figsize=(30, 16), color = "purple", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind5,fontsize = 18)
plt.ylabel("")
plt.title("Who has tied the most in the premier league mid-season of 2019/20?", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ### TOP GOAL SCORERS

# %%
body = client_e62b6c1bb76c4710b1d1cc5aeab9a929.get_object(Bucket='databel-donotdelete-pr-d4qsbyzwywn9lq',Key='TOP GOALSCORERS - Sheet1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#   Rank                     Player               Club Nationality  Stat
# 0    1                Jamie Vardy     Leicester City     England  17.0
# 1    2  Pierre-Emerick Aubameyang            Arsenal       Gabon  12.0
# 2    3              Tammy Abraham            Chelsea     England  11.0
# 3    3                 Danny Ings        Southampton     England  11.0
# 4    3            Marcus Rashford  Manchester United     England  11.0

# %%
df_goal = df_data_2.head(20)

# %%
df_goal
# Out:
#    Rank                     Player                      Club  Nationality  \
# 0     1                Jamie Vardy            Leicester City      England
# 1     2  Pierre-Emerick Aubameyang                   Arsenal        Gabon
# 2     3              Tammy Abraham                   Chelsea      England
# 3     3                 Danny Ings               Southampton      England
# 4     3            Marcus Rashford         Manchester United      England
# 5     3            Raheem Sterling           Manchester City      England
# 6     7                 Harry Kane         Tottenham Hotspur      England
# 7     8              Sergio Agüero           Manchester City    Argentina
# 8     8                 Sadio Mané                 Liverpool      Senegal
# 9     8                Teemu Pukki              Norwich City      Finland
# 10    8              Mohamed Salah                 Liverpool        Egypt
# 11   12               Raúl Jiménez   Wolverhampton Wanderers       Mexico
# ...

# %%
df_goal2 = df_goal[['Player', 'Stat']].sort_values(by = "Stat", ascending = True)

# %%
ind6 = df_goal2.set_index("Player", inplace = True)

# %%
## A horizontal bar graph showing the highest goal scorers in the premier league after 19 games
bar = df_goal2.plot(kind='barh',figsize=(30, 16), color = "green", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind6,fontsize = 18)
plt.ylabel("")
plt.title("The highest goalscorers in the premier league mid-season of 2019/20", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ### TOP ASSIST MAKERS

# %%
body = client_e62b6c1bb76c4710b1d1cc5aeab9a929.get_object(Bucket='databel-donotdelete-pr-d4qsbyzwywn9lq',Key='TOP ASSIST MAKERS - Sheet1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_3 = pd.read_csv(body)
df_data_3.head()
# Out:
#   Rank                  Player                     Club  Nationality  Stat
# 0    1         Kevin De Bruyne          Manchester City      Belgium  11.0
# 1    2  Trent Alexander-Arnold                Liverpool      England   8.0
# 2    3           Son Heung-Min        Tottenham Hotspur  South Korea   7.0
# 3    4            Raúl Jiménez  Wolverhampton Wanderers       Mexico   6.0
# 4    4              Sadio Mané                Liverpool      Senegal   6.0

# %%
df_assist = df_data_3.head(20)

# %%
df_assist2 = df_assist[['Player', 'Stat']].sort_values(by = "Stat", ascending = True)

# %%
ind7 = df_assist2.set_index('Player', inplace = True)

# %%
## A horizontal bar graph showing the highest assist makers in the premier league after 19 games
bar = df_assist2.plot(kind='barh',figsize=(30, 16), color = "orange", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind7,fontsize = 18)
plt.ylabel("")
plt.title("The best playmakers in the premier league mid-season of 2019/20", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ### CLEAN SHEETS

# %%
body = client_e62b6c1bb76c4710b1d1cc5aeab9a929.get_object(Bucket='databel-donotdelete-pr-d4qsbyzwywn9lq',Key='TEAM CLEAN SHEETS - Sheet1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_4 = pd.read_csv(body)
df_data_4.head()
# Out:
#   Rank             Player              Club Nationality  Stat
# 0    1     Dean Henderson  Sheffield United     England   7.0
# 1    1          Nick Pope           Burnley     England   7.0
# 2    1  Kasper Schmeichel    Leicester City     Denmark   7.0
# 3    4     Vicente Guaita    Crystal Palace       Spain   6.0
# 4    4            Ederson   Manchester City      Brazil   6.0

# %%
df_cleansheet = df_data_4.head(20)

# %%
df_cleansheet
# Out:
#    Rank             Player                      Club  Nationality  Stat
# 0     1     Dean Henderson          Sheffield United      England   7.0
# 1     1          Nick Pope                   Burnley      England   7.0
# 2     1  Kasper Schmeichel            Leicester City      Denmark   7.0
# 3     4     Vicente Guaita            Crystal Palace        Spain   6.0
# 4     4            Ederson           Manchester City       Brazil   6.0
# 5     6    Martin Dubravka          Newcastle United     Slovakia   5.0
# 6     6         Ben Foster                   Watford      England   5.0
# 7     6    Jordan Pickford                   Everton      England   5.0
# 8     9  Kepa Arrizabalaga                   Chelsea        Spain   4.0
# 9     9       Rui Patrício   Wolverhampton Wanderers     Portugal   4.0
# 10    9         Tom Heaton               Aston Villa      England   4.0
# 11    9     Aaron Ramsdale           AFC Bournemouth      England   4.0
# ...

# %%
df_cleansheet2 = df_cleansheet[['Player', 'Stat']].sort_values(by = 'Stat', ascending = True)

# %%
ind8 = df_cleansheet2.set_index("Player", inplace = True)

# %%
## A horizontal bar graph showing the goalkeeper's clean sheets in the premier league after 19 games
bar = df_cleansheet2.plot(kind='barh',figsize=(30, 16), color = "brown", legend = None)
bar
plt.yticks(fontsize = 24)
plt.xticks(ind8,fontsize = 18)
plt.ylabel("")
plt.title("Clean sheets in the premier league mid-season of 2019/20", fontsize=32)
bar.spines['top'].set_visible(False)
bar.spines['right'].set_visible(False)
bar.spines['bottom'].set_linewidth(0.5)
bar.spines['left'].set_visible(True)
plt.show()
